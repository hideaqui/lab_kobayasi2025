# %% [markdown]
# ## npy の中身をチェックするだけ

# %%
import numpy as np

loaded_array_1 = np.load('epoch_0_layer1.npy')
loaded_array_2 = np.load('epoch_0_layer2.npy')
loaded_array_3 = np.load('epoch_0_layer3.npy')
loaded_array_4 = np.load('epoch_0_layer4.npy')

print("--- ファイル読み込み完了 ---")
print("読み込んだ配列:")
print(loaded_array_1)
print(loaded_array_2)
print(loaded_array_3)
print(loaded_array_4)
# Out:
# --- ファイル読み込み完了 ---
# 読み込んだ配列:
# [[[[0.00000000e+00 2.36510560e-02 2.20837981e-01 ... 3.29096168e-01
#     3.69810373e-01 2.84231395e-01]
#    [0.00000000e+00 2.95916587e-01 5.80067337e-01 ... 7.30777502e-01
#     7.82843232e-01 4.64193851e-01]
#    [2.79076636e-01 7.67451167e-01 9.20083165e-01 ... 9.97886419e-01
#     9.75097895e-01 8.12546253e-01]
#    ...
#    [1.31140888e-01 3.28589439e-01 3.21910501e-01 ... 8.99365187e-01
#     5.96359968e-01 1.04090571e+00]
#    [1.04012638e-01 0.00000000e+00 5.96732274e-02 ... 1.43164441e-01
#     8.71183872e-02 4.65278059e-01]
#    [4.10417952e-02 1.44528523e-02 2.27031857e-03 ... 1.42585844e-01
#     1.58974290e-01 2.65344530e-01]]
#
#   [[2.77774269e-03 0.00000000e+00 0.00000000e+00 ... 1.13198161e-01
#     2.11182311e-02 7.36252069e-02]
#    [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#     0.00000000e+00 0.00000000e+00]
#    [0.00000000e+00 2.41846442e-01 1.24678642e-01 ... 0.00000000e+00
# ...

# %%
import numpy as np

loaded_array_1 = np.load('epoch_2_layer1.npy')
loaded_array_2 = np.load('epoch_2_layer2.npy')
loaded_array_3 = np.load('epoch_2_layer3.npy')
loaded_array_4 = np.load('epoch_3_layer4.npy')

print("--- ファイル読み込み完了 ---")
print("読み込んだ配列:")
print(loaded_array_1)
print(loaded_array_2)
print(loaded_array_3)
print(loaded_array_4)
# Out:
# --- ファイル読み込み完了 ---
# 読み込んだ配列:
# [[[[2.0339353  2.537999   2.569953   ... 1.9719498  1.6842885
#     1.657994  ]
#    [1.4919044  2.7363038  2.4149704  ... 0.5834369  0.6079559
#     1.7674434 ]
#    [1.7360895  2.5336623  1.1181597  ... 1.9700326  1.9235893
#     2.0341508 ]
#    ...
#    [0.549122   2.315688   3.3035636  ... 0.         0.
#     1.0717261 ]
#    [0.10872152 1.936209   0.6974983  ... 0.32916418 1.0710878
#     3.0978394 ]
#    [1.5985618  1.8648111  1.7094209  ... 2.8276482  2.8419092
#     2.3751926 ]]
#
#   [[0.76023996 0.60677224 0.8372389  ... 0.4677154  0.36546636
#     0.795667  ]
#    [1.1820151  0.9807503  0.59596777 ... 0.         0.
#     0.6287531 ]
#    [0.9760535  0.22353888 0.         ... 2.3853686  2.014741
#     1.0979829 ]
#    ...
#    [1.6633126  3.4691906  3.5900254  ... 1.6862497  0.
#     0.        ]
#    [2.352788   3.1791317  1.6002077  ... 0.         0.21799046
#     1.2660238 ]
#    [2.5934181  2.699633   1.2189211  ... 1.7597166  2.222125
# ...
